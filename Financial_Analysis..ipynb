# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('finance_economics_dataset.csv')
df.drop_duplicates()
# Out:
#             Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0     2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1     2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2     2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3     2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4     2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
# ...          ...         ...         ...          ...         ...        ...
# 2995  2008-03-14   Dow Jones     1273.76      1235.44     1317.28    1192.34
# 2996  2008-03-15     S&P 500     4589.59      4566.91     4607.56    4545.69
# 2997  2008-03-16     S&P 500     1477.52      1448.47     1523.86    1402.69
# 2998  2008-03-17      NASDAQ     2311.37      2306.90     2346.30    2282.00
# 2999  2008-03-18      NASDAQ     4262.98      4303.82     4316.68    4243.04
#
# ...

# %%
df.convert_dtypes()
# Out:
#             Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0     2000-01-01   Dow Jones     2128.75      2138.48      2143.7    2100.55
# 1     2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2     2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3     2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4     2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
# ...          ...         ...         ...          ...         ...        ...
# 2995  2008-03-14   Dow Jones     1273.76      1235.44     1317.28    1192.34
# 2996  2008-03-15     S&P 500     4589.59      4566.91     4607.56    4545.69
# 2997  2008-03-16     S&P 500     1477.52      1448.47     1523.86    1402.69
# 2998  2008-03-17      NASDAQ     2311.37       2306.9      2346.3     2282.0
# 2999  2008-03-18      NASDAQ     4262.98      4303.82     4316.68    4243.04
#
# ...

# %% [markdown]
# ## 1. What is the shape of the dataset?

# %%
df.shape
# Out:
# (3000, 24)

# %% [markdown]
# ## 2. What are the column names and their data types?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Date                                   3000 non-null   object
#  1   Stock Index                            3000 non-null   object
#  2   Open Price                             3000 non-null   float64
#  3   Close Price                            3000 non-null   float64
#  4   Daily High                             3000 non-null   float64
#  5   Daily Low                              3000 non-null   float64
#  6   Trading Volume                         3000 non-null   int64
#  7   GDP Growth (%)                         3000 non-null   float64
#  8   Inflation Rate (%)                     3000 non-null   float64
#  9   Unemployment Rate (%)                  3000 non-null   float64
# ...

# %% [markdown]
# ## 3. How many unique stock indices are there?

# %%
df['Stock Index'].unique()
# Out:
# array(['Dow Jones', 'S&P 500', 'NASDAQ'], dtype=object)

# %% [markdown]
# ## 4. What is the date range of the dataset?

# %%
date_min = df['Date'].min()
date_max = df['Date'].max()
print(f"Data ranges from {date_min} to {date_max}")
# Out:
# Data ranges from 2000-01-01 to 2008-03-18

# %% [markdown]
# ## 5. Are there any missing values?

# %%
df.isna().count()
# Out:
# Date                                     3000
# Stock Index                              3000
# Open Price                               3000
# Close Price                              3000
# Daily High                               3000
# Daily Low                                3000
# Trading Volume                           3000
# GDP Growth (%)                           3000
# Inflation Rate (%)                       3000
# Unemployment Rate (%)                    3000
# Interest Rate (%)                        3000
# Consumer Confidence Index                3000
# Government Debt (Billion USD)            3000
# Corporate Profits (Billion USD)          3000
# Forex USD/EUR                            3000
# Forex USD/JPY                            3000
# Crude Oil Price (USD per Barrel)         3000
# Gold Price (USD per Ounce)               3000
# Real Estate Index                        3000
# Retail Sales (Billion USD)               3000
# ...

# %% [markdown]
# ## 6. Are there negative values in columns that should be non-negative?

# %%
df1 = df.select_dtypes(include='number')
negative = (df1 < 0).any()
negative
# Out:
# Open Price                               False
# Close Price                              False
# Daily High                               False
# Daily Low                                False
# Trading Volume                           False
# GDP Growth (%)                            True
# Inflation Rate (%)                       False
# Unemployment Rate (%)                    False
# Interest Rate (%)                        False
# Consumer Confidence Index                False
# Government Debt (Billion USD)            False
# Corporate Profits (Billion USD)          False
# Forex USD/EUR                            False
# Forex USD/JPY                            False
# Crude Oil Price (USD per Barrel)         False
# Gold Price (USD per Ounce)               False
# Real Estate Index                        False
# Retail Sales (Billion USD)               False
# Bankruptcy Rate (%)                      False
# Mergers & Acquisitions Deals             False
# ...

# %% [markdown]
# ### Answer = No

# %% [markdown]
# ### 7. What is the summary of GDP Growth (%)?

# %%
df['GDP Growth (%)'].describe()
# Out:
# count    3000.000000
# mean        2.608903
# std         4.287337
# min        -5.000000
# 25%        -1.012500
# 50%         2.725000
# 75%         6.242500
# max        10.000000
# Name: GDP Growth (%), dtype: float64

# %% [markdown]
# ### 8. Are there rows with zero or near-zero trading volume?

# %%
# df['Trading Volume'] < 0 and df['Trading Volume'] < 1
df2 = np.where((df['Trading Volume'] <= 0) | (df['Trading Volume'] < 1)) 
df2
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### Answer = No

# %% [markdown]
# ### 9. Are there any duplicate rows?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Answer = No

# %% [markdown]
# ### 10. Are there outliers in GDP, Gold, or Oil prices?

# %%
plt.boxplot(df['GDP Growth (%)'])
plt.title('GDP Growth (%)')
plt.show()
plt.boxplot(df['Crude Oil Price (USD per Barrel)'])
plt.title('Crude Oil Price (USD per Barrel)')
plt.show()
plt.boxplot(df['Gold Price (USD per Ounce)'])
plt.title('Gold Price (USD per Ounce)')
plt.show()

# %% [markdown]
# ### Answer = No

# %% [markdown]
# ## 11. What is the summary of Inflation Rate (%)?

# %%
df['Inflation Rate (%)'].describe()
# Out:
# count    3000.000000
# mean        5.096830
# std         2.910513
# min         0.010000
# 25%         2.607500
# 50%         5.110000
# 75%         7.600000
# max        10.000000
# Name: Inflation Rate (%), dtype: float64

# %% [markdown]
# ## 12. What is the average unemployment rate?

# %%
df['Unemployment Rate (%)'].mean()
# Out:
# np.float64(8.663786666666667)

# %% [markdown]
# ## 13. Which index has the highest trading volume?

# %%
df3 = df.loc[df['Trading Volume'] == df['Trading Volume'].max()]
df3
# df3['Stock Index']
# Out:
#            Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 641  2001-10-03     S&P 500     2192.21      2199.49     2240.85     2142.9
#
#      Trading Volume  GDP Growth (%)  Inflation Rate (%)  \
# 641       999977078            6.05                8.58
#
#      Unemployment Rate (%)  ...  Forex USD/EUR  Forex USD/JPY  \
# 641                   12.2  ...           1.14         130.31
#
#      Crude Oil Price (USD per Barrel)  Gold Price (USD per Ounce)  \
# 641                             35.87                     1385.15
#
#      Real Estate Index  Retail Sales (Billion USD)  Bankruptcy Rate (%)  \
# 641             240.43                        2244                 6.05
#
#      Mergers & Acquisitions Deals  Venture Capital Funding (Billion USD)  \
# 641                            47                                  23.06
#
#      Consumer Spending (Billion USD)
# 641                             1797
#
# [1 rows x 24 columns]

# %% [markdown]
# ## 14. How many stock records are from each index?

# %%
df['Stock Index'].value_counts().reset_index()
# Out:
#   Stock Index  count
# 0     S&P 500   1036
# 1      NASDAQ   1007
# 2   Dow Jones    957

# %% [markdown]
# ## 15. What is the correlation between inflation and interest rate?

# %%
df4 = df['Inflation Rate (%)'].corr(df['Interest Rate (%)'])
df4
# Out:
# np.float64(0.00573292723557624)

# %% [markdown]
# ## 16. What is the average Consumer Confidence Index?

# %%
df['Consumer Confidence Index'].mean()
# Out:
# np.float64(85.036)

# %% [markdown]
# ## 17. Which column has the highest standard deviation?

# %%
df.describe()
df.select_dtypes(include='number').std().idxmax()
# Out:
# 'Trading Volume'

# %% [markdown]
# ## 18. What is the highest gold price recorded?

# %%
df5 = df.loc[df['Gold Price (USD per Ounce)'] == df['Gold Price (USD per Ounce)'].max()]
df5
# Out:
#            Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 478  2001-04-23     S&P 500     4162.04      4181.38     4213.88    4125.73
#
#      Trading Volume  GDP Growth (%)  Inflation Rate (%)  \
# 478       882697483            0.89                2.22
#
#      Unemployment Rate (%)  ...  Forex USD/EUR  Forex USD/JPY  \
# 478                    5.5  ...           1.34          96.77
#
#      Crude Oil Price (USD per Barrel)  Gold Price (USD per Ounce)  \
# 478                             73.35                     2499.66
#
#      Real Estate Index  Retail Sales (Billion USD)  Bankruptcy Rate (%)  \
# 478              370.8                        8541                 4.35
#
#      Mergers & Acquisitions Deals  Venture Capital Funding (Billion USD)  \
# 478                             9                                  73.14
#
#      Consumer Spending (Billion USD)
# 478                             2992
#
# [1 rows x 24 columns]

# %% [markdown]
# ## 19. Which date had the highest crude oil price?

# %%
df6 = df.loc[df['Crude Oil Price (USD per Barrel)'] == df['Crude Oil Price (USD per Barrel)'].max()]
df6['Date']
# Out:
# 691    2001-11-22
# Name: Date, dtype: object

# %% [markdown]
# ## 20. What is the average corporate profit?

# %%
df['Corporate Profits (Billion USD)'].mean()
# Out:
# np.float64(2553.7563333333333)

# %% [markdown]
# # Insightful Analysis Questions

# %% [markdown]
# ## 1. What percentage of the dataset shows negative GDP growth?

# %%
neg = (df['GDP Growth (%)'] < 0).sum()
# neg
per = ((neg/len(df['GDP Growth (%)']))*100)
per
# len(df['GDP Growth (%)'])
# Out:
# np.float64(31.566666666666666)

# %% [markdown]
# ## 2. Does high inflation correspond to higher interest rates?

# %%
df[['Inflation Rate (%)', 'Interest Rate (%)']].plot.hist(alpha=0.5, bins= 50)
plt.show()

# %% [markdown]
# ### 3. Is there a relationship between unemployment and consumer spending?

# %%
df[['Unemployment Rate (%)', 'Consumer Spending (Billion USD)']].hist(alpha=0.5, bins= 50)
plt.show()

# %% [markdown]
# ### 4. Do higher corporate profits align with higher consumer confidence?

# %%
df[['Corporate Profits (Billion USD)', 'Consumer Confidence Index']].hist(alpha=0.5, bins= 50)
plt.show()

# %%
plt.scatter(df1['Corporate Profits (Billion USD)'],df1['Consumer Confidence Index'],marker = "o",color = "blue")
plt.show()

# %% [markdown]
# ### 5. What’s the trend of crude oil prices over time?

# %%
sns.lineplot(data=df,x="Date",y="Crude Oil Price (USD per Barrel)",marker="o",color="red")
plt.title("Crude Oil Price Over Time")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Are gold prices inversely related to stock performance?

# %%
correlation = df['Close Price'].corr(df['Gold Price (USD per Ounce)'])
print(f"Correlation between Stocks and Gold: {correlation:.2f}")
# Out:
# Correlation between Stocks and Gold: -0.01

# %% [markdown]
# ### Answer : No

# %% [markdown]
# ## 7. Does government debt impact consumer confidence?

# %%
debt_confidence_corr = df['Government Debt (Billion USD)'].corr(df['Consumer Confidence Index'])
print(f"Correlation: {debt_confidence_corr:.2f}")
# Out:
# Correlation: -0.04

# %% [markdown]
# ### Answer : No

# %% [markdown]
# ## 8. How do mergers & acquisitions (M&A) activity correlate with stock index closing prices?

# %%
ma_stock_corr = df['Mergers & Acquisitions Deals'].corr(df['Close Price'])
print(f"Correlation between M&A Activity and Stock Index: {ma_stock_corr:.2f}")
# Out:
# Correlation between M&A Activity and Stock Index: 0.00

# %% [markdown]
# ### No relation

# %% [markdown]
# ## 9. Is retail sales growth associated with GDP growth?

# %%
Retail_corr = df['Retail Sales (Billion USD)'].corr(df['GDP Growth (%)'])
print(f"Correlation between Retail Sales (Billion USD) & GDP Growth (%) : {Retail_corr:.2f}")
# Out:
# Correlation between Retail Sales (Billion USD) & GDP Growth (%) : -0.01

# %% [markdown]
# ### No Relation

# %% [markdown]
# ## 10. Is stock market performance linked to consumer spending?

# %%
spending_corr = df['Close Price'].corr(df['Consumer Spending (Billion USD)'])
print(f"Correlation with Consumer Spending: {spending_corr:.2f}")
# Out:
# Correlation with Consumer Spending: 0.00

# %% [markdown]
# ## 11. Which stock index had the highest average closing price?

# %%
df01 = df.groupby('Stock Index')['Close Price'].mean()
df01.idxmax()
# Out:
# 'Dow Jones'

# %% [markdown]
# ## 12. What is the relationship between interest rate and unemployment?

# %%
interest_rate_corr = df['Interest Rate (%)'].corr(df['Unemployment Rate (%)'])
print(f"Correlation with interest rate & Unemployment Rate: {interest_rate_corr:.2f}")
# Out:
# Correlation with interest rate & Unemployment Rate: 0.02

# %% [markdown]
# ## 13. Do lower consumer confidence values coincide with higher bankruptcy rates?

# %%
consumer_corr = df['Consumer Confidence Index'].corr(df['Bankruptcy Rate (%)'])
print(f"Correlation: {consumer_corr:.2f}")
# Out:
# Correlation: -0.02

# %% [markdown]
# ## 14. Which indicator has the highest correlation with stock close price?

# %%
stock_price_corr = df.select_dtypes(include=['number']).corr()['Close Price']
stock_price_corr.sort_values(ascending=False).reset_index()
stock_price_corr.iloc[0:4]
# Out:
# Open Price     0.999688
# Close Price    1.000000
# Daily High     0.999821
# Daily Low      0.999820
# Name: Close Price, dtype: float64

# %% [markdown]
# ## 15. Are unemployment rates lower when corporate profits are high?

# %%
df['Corporate Profits (Billion USD)'].corr(df['Unemployment Rate (%)'])
# Out:
# np.float64(0.008292414188235554)
